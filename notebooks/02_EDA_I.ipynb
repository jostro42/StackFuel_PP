# %% [markdown]
# # EDA I
#
# Here we will explore the reformatted metacritic data set.

# %% [markdown]
# ## Setup

# %%
# +++ load packages +++

from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from IPython.display import display

from core.config import DATA_FORMATTED_PATH
from eda.overview import overview

# %%
# Load the formatted data
if not DATA_FORMATTED_PATH.is_file():
    raise FileNotFoundError(
        f"Formatted dataset not found: {DATA_FORMATTED_PATH}. "
        "Run 01_LoadData_Reformatting.ipynb through its final save cell first."
    )
df = pd.read_csv(DATA_FORMATTED_PATH)
df.head(10)
# Out:
#              title        genre  \
# 0         Tekken 3  3D Fighting
# 1         Tekken 3  3D Fighting
# 2    Mass Effect 2  Western RPG
# 3    Mass Effect 2  Western RPG
# 4    Mass Effect 2  Western RPG
# 5  Baldur's Gate 3  Western RPG
# 6  Baldur's Gate 3  Western RPG
# 7  Baldur's Gate 3  Western RPG
# 8   The Orange Box  Compilation
# 9   The Orange Box  Compilation
#
#                                              summary         publisherName  \
# 0  An ancient evil force has reawakened, attackin...                 Namco
# 1  An ancient evil force has reawakened, attackin...                 Namco
# 2  The Mass Effect trilogy is a science fiction a...       Electronic Arts
# 3  The Mass Effect trilogy is a science fiction a...       Electronic Arts
# 4  The Mass Effect trilogy is a science fiction a...       Electronic Arts
# 5  An ancient evil has returned to Baldur's Gate,...  Larian Studios Games
# 6  An ancient evil has returned to Baldur's Gate,...  Larian Studios Games
# 7  An ancient evil has returned to Baldur's Gate,...  Larian Studios Games
# 8  Games included in The Orange Box compilation: ...              EA Games
# 9  Games included in The Orange Box compilation: ...              EA Games
#
#                                         publisherUrl  \
# 0          https://www.metacritic.com/company/namco/
# 1          https://www.metacritic.com/company/namco/
# 2  https://www.metacritic.com/company/electronic-...
# 3  https://www.metacritic.com/company/electronic-...
# 4  https://www.metacritic.com/company/electronic-...
# 5  https://www.metacritic.com/company/larian-stud...
# 6  https://www.metacritic.com/company/larian-stud...
# 7  https://www.metacritic.com/company/larian-stud...
# 8       https://www.metacritic.com/company/ea-games/
# 9       https://www.metacritic.com/company/ea-games/
#
#                                               url original_platform  \
# 0        https://www.metacritic.com/game/tekken-3       PlayStation
# 1        https://www.metacritic.com/game/tekken-3       PlayStation
# 2   https://www.metacritic.com/game/mass-effect-2          Xbox 360
# 3   https://www.metacritic.com/game/mass-effect-2          Xbox 360
# 4   https://www.metacritic.com/game/mass-effect-2          Xbox 360
# 5  https://www.metacritic.com/game/baldurs-gate-3                PC
# 6  https://www.metacritic.com/game/baldurs-gate-3                PC
# 7  https://www.metacritic.com/game/baldurs-gate-3                PC
# 8  https://www.metacritic.com/game/the-orange-box          Xbox 360
# 9  https://www.metacritic.com/game/the-orange-box          Xbox 360
#
#   ReleaseDate       platform  metascore  ...  userscore  user_positive_count  \
# 0  1998-04-29    PlayStation       96.0  ...        8.9                990.0
# 1  1998-04-29      Dreamcast        NaN  ...        NaN                  NaN
# 2  2010-01-26             PC       94.0  ...        NaN                  NaN
# 3  2010-01-26       Xbox 360       96.0  ...        8.9               2792.0
# 4  2010-01-26  PlayStation 3       94.0  ...        NaN                  NaN
# 5  2023-08-03             PC       96.0  ...        9.2              16167.0
# 6  2023-08-03  PlayStation 5       96.0  ...        NaN                  NaN
# 7  2023-08-03  Xbox Series X       99.0  ...        NaN                  NaN
# 8  2007-10-10             PC       96.0  ...        NaN                  NaN
# 9  2007-10-10       Xbox 360       96.0  ...        8.8                675.0
#
#    user_negative_count  user_mixed_count  user_total_count   critic_sourceVar  \
# 0                 35.0              77.0            1102.0  platformReviews/0
# 1                  NaN               NaN               NaN  platformReviews/1
# 2                  NaN               NaN               NaN  platformReviews/0
# 3                128.0             164.0            3084.0  platformReviews/1
# 4                  NaN               NaN               NaN  platformReviews/2
# 5               1099.0             653.0           17919.0  platformReviews/0
# 6                  NaN               NaN               NaN  platformReviews/1
# 7                  NaN               NaN               NaN  platformReviews/2
# 8                  NaN               NaN               NaN  platformReviews/0
# 9                 38.0              62.0             775.0  platformReviews/1
#
#                                    critic_review_url  userscore_sourceVar  \
# 0  https://www.metacritic.com/game/tekken-3/criti...            userscore
# 1  https://www.metacritic.com/game/tekken-3/criti...                  NaN
# 2  https://www.metacritic.com/game/mass-effect-2/...                  NaN
# 3  https://www.metacritic.com/game/mass-effect-2/...            userscore
# 4  https://www.metacritic.com/game/mass-effect-2/...                  NaN
# 5  https://www.metacritic.com/game/baldurs-gate-3...            userscore
# 6  https://www.metacritic.com/game/baldurs-gate-3...                  NaN
# 7  https://www.metacritic.com/game/baldurs-gate-3...                  NaN
# 8  https://www.metacritic.com/game/the-orange-box...                  NaN
# 9  https://www.metacritic.com/game/the-orange-box...            userscore
#
#    user_review_sourceVar  critic_observation_count
# 0     userReviewsSummary                         1
# 1                    NaN                         1
# 2                    NaN                         1
# 3     userReviewsSummary                         1
# 4                    NaN                         1
# 5     userReviewsSummary                         1
# 6                    NaN                         1
# 7                    NaN                         1
# 8                    NaN                         1
# 9     userReviewsSummary                         1
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Initial Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35162 entries, 0 to 35161
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     35162 non-null  object
#  1   genre                     35162 non-null  object
#  2   summary                   35097 non-null  object
#  3   publisherName             35160 non-null  object
#  4   publisherUrl              35160 non-null  object
#  5   url                       35162 non-null  object
#  6   original_platform         35162 non-null  object
#  7   ReleaseDate               35115 non-null  object
#  8   platform                  35162 non-null  object
#  9   metascore                 25099 non-null  float64
#  10  critic_normalized_score   25099 non-null  float64
#  11  critic_positive_count     29870 non-null  float64
#  12  critic_negative_count     29870 non-null  float64
#  13  critic_mixed_count        29870 non-null  float64
#  14  critic_total_count        29870 non-null  float64
#  15  userscore                 11896 non-null  float64
#  16  user_positive_count       13428 non-null  float64
#  17  user_negative_count       13428 non-null  float64
#  18  user_mixed_count          13428 non-null  float64
#  19  user_total_count          13428 non-null  float64
#  20  critic_sourceVar          35162 non-null  object
#  21  critic_review_url         35162 non-null  object
#  22  userscore_sourceVar       13429 non-null  object
#  23  user_review_sourceVar     13429 non-null  object
#  24  critic_observation_count  35162 non-null  int64
# dtypes: float64(11), int64(1), object(13)
# memory usage: 6.7+ MB

# %%
ov, num_vars, cat_vars = overview(df)
# Out:
# Duplicates: 0
#
# Auto Sales Data - Variable Overview
#                             dtype  total  missing_n  missing_%  uniques_n  \
# title                      object  35162          0   0.000000      13429
# genre                      object  35162          0   0.000000        119
# summary                    object  35097         65   0.184859      13314
# publisherName              object  35160          2   0.005688       2038
# publisherUrl               object  35160          2   0.005688       2038
# url                        object  35162          0   0.000000      13429
# original_platform          object  35162          0   0.000000         22
# ReleaseDate                object  35115         47   0.133667       4761
# platform                   object  35162          0   0.000000         23
# metascore                 float64  25099      10063  28.618964         87
# critic_normalized_score   float64  25099      10063  28.618964      11188
# critic_positive_count     float64  29870       5292  15.050338        125
# critic_negative_count     float64  29870       5292  15.050338         41
# critic_mixed_count        float64  29870       5292  15.050338         65
# critic_total_count        float64  29870       5292  15.050338        142
# userscore                 float64  11896      23266  66.168022         93
# user_positive_count       float64  13428      21734  61.811046       1083
# user_negative_count       float64  13428      21734  61.811046        509
# user_mixed_count          float64  13428      21734  61.811046        485
# user_total_count          float64  13428      21734  61.811046       1300
# critic_sourceVar           object  35162          0   0.000000         12
# critic_review_url          object  35162          0   0.000000      35162
# userscore_sourceVar        object  13429      21733  61.808202          1
# user_review_sourceVar      object  13429      21733  61.808202          1
# critic_observation_count    int64  35162          0   0.000000          3
#
#                                                                     uniques
# title                     [Tekken 3, Mass Effect 2, Baldur's Gate 3, The...
# genre                     [3D Fighting, Western RPG, Compilation, Linear...
# summary                   [An ancient evil force has reawakened, attacki...
# publisherName             [Namco, Electronic Arts, Larian Studios Games,...
# publisherUrl              [https://www.metacritic.com/company/namco/, ht...
# url                       [https://www.metacritic.com/game/tekken-3, htt...
# original_platform         [PlayStation, Xbox 360, PC, PlayStation 3, Gam...
# ReleaseDate               [1998-04-29, 2010-01-26, 2023-08-03, 2007-10-1...
# platform                  [PlayStation, Dreamcast, PC, Xbox 360, PlaySta...
# metascore                 [96.0, nan, 94.0, 99.0, 89.0, 76.0, 91.0, 68.0...
# critic_normalized_score   [96.0, nan, 94.2078, 95.9254, 94.1395, 96.0672...
# critic_positive_count     [15.0, nan, 54.0, 98.0, 62.0, 111.0, 37.0, 9.0...
# critic_negative_count     [0.0, nan, 1.0, 2.0, 10.0, 9.0, 5.0, 3.0, 19.0...
# critic_mixed_count        [0.0, nan, 1.0, 7.0, 8.0, 4.0, 2.0, 5.0, 3.0, ...
# critic_total_count        [15.0, nan, 55.0, 98.0, 62.0, 119.0, 39.0, 10....
# userscore                 [8.899999618530273, nan, 9.199999809265137, 8....
# user_positive_count       [990.0, nan, 2792.0, 16167.0, 675.0, 6548.0, 2...
# user_negative_count       [35.0, nan, 128.0, 1099.0, 38.0, 353.0, 109.0,...
# user_mixed_count          [77.0, nan, 164.0, 653.0, 62.0, 430.0, 113.0, ...
# user_total_count          [1102.0, nan, 3084.0, 17919.0, 775.0, 7331.0, ...
# critic_sourceVar          [platformReviews/0, platformReviews/1, platfor...
# critic_review_url         [https://www.metacritic.com/game/tekken-3/crit...
# userscore_sourceVar                                        [userscore, nan]
# user_review_sourceVar                             [userReviewsSummary, nan]
# critic_observation_count                                          [1, 2, 3]
# Descriptive Metrics on numeric variables
#                             count        mean          std      min       25%  \
# metascore                 25099.0   71.059723    12.057697  11.0000  64.00000
# critic_normalized_score   25099.0   71.035122    12.052750  10.6667  64.31295
# critic_positive_count     29870.0    9.946836    14.738932   0.0000   1.00000
# critic_negative_count     29870.0    1.111014     2.791743   0.0000   0.00000
# critic_mixed_count        29870.0    6.223770     7.120516   0.0000   1.00000
# critic_total_count        29870.0   17.521627    17.829740   0.0000   6.00000
# userscore                 11896.0    6.929203     1.358217   0.3000   6.30000
# user_positive_count       13428.0  153.327674  1076.816276   0.0000   4.00000
# user_negative_count       13428.0   45.677688   685.682147   0.0000   1.00000
# user_mixed_count          13428.0   32.124218   125.633971   0.0000   2.00000
# user_total_count          13428.0  231.129580  1748.085127   0.0000   9.00000
# critic_observation_count  35162.0    1.000882     0.030623   1.0000   1.00000
#
#                               50%      75%          max
# metascore                 73.0000  80.0000      99.0000
# critic_normalized_score   72.7917  79.6667      99.1111
# critic_positive_count      4.0000  12.0000     145.0000
# critic_negative_count      0.0000   1.0000      51.0000
# critic_mixed_count         4.0000   8.0000      77.0000
# critic_total_count        11.0000  23.0000     156.0000
# userscore                  7.2000   7.9000      10.0000
# user_positive_count       14.0000  57.2500   87266.0000
# user_negative_count        4.0000  14.0000   68090.0000
# user_mixed_count           6.0000  21.0000    8875.0000
# user_total_count          27.0000  99.0000  164231.0000
# critic_observation_count   1.0000   1.0000       3.0000
# Numeric Variables in the data set
#                             dtype
# metascore                 float64
# critic_normalized_score   float64
# critic_positive_count     float64
# critic_negative_count     float64
# critic_mixed_count        float64
# critic_total_count        float64
# userscore                 float64
# user_positive_count       float64
# user_negative_count       float64
# user_mixed_count          float64
# user_total_count          float64
# critic_observation_count    int64
# Non-numeric variables in the data set
#                         dtype  n_uniques
# title                  object      13429
# genre                  object        119
# summary                object      13314
# publisherName          object       2038
# publisherUrl           object       2038
# url                    object      13429
# original_platform      object         22
# ReleaseDate            object       4761
# platform               object         23
# critic_sourceVar       object         12
# critic_review_url      object      35162
# userscore_sourceVar    object          1
# user_review_sourceVar  object          1

# %% [markdown]
# #### Insights
#
# - **Metadata**
#     - only small number of entries with missing values in `summary`, publisher, and `releaseDate`
#     - All columns coded as object. Think about potential transformations for ease of use further on
#     - `platform` might be the only meta variable with a number of classes still usable with potential OHE later on. We'll need to think about how to best use the information hidden in `genre` and `publisher`
#     - Year and month (and maybe even day) needs to be extracted and cyclically transformed from `releaseDate`
#     - transformation of columns containing text (genre, summary, urls) to string?
# - **Scores and counts**
#     - a lot of missing data in critic and user variables. However, given the prior reformatting this is not too surprising. The original data set had 1 row per game, with addition information on scores and counts per platform hidden in a multitude of columns. By transforming into a game-platform format where we have multiple rows per game (1 per game platform combination), we automatically created rows with missing values. For some game-platform combinations, the score and review counts were unavailable
#     - User score and counts were only available for the platform stated in the `section` variable of the original data set. Which is why we have ~60% missing values in the `user_[...]` variables. We went from 1 row to 3-4 rows per game on average, explaining the entry gap.
#     - Ideally, missing values will be filled with subsequent scrapes.
#     - Counts and critic scores need to be transformed to integers
#     - vastly more usser counts than critic counts...weighted counts needed for comparison!
